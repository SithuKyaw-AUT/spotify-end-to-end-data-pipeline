# %%
# !pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.24.0-py3-none-any.whl (30 kB)
# Requirement already satisfied: requests>=2.25.0 in c:\programdata\anaconda3\lib\site-packages (from spotipy) (2.26.0)
# Collecting redis>=3.5.3
#   Downloading redis-5.0.8-py3-none-any.whl (255 kB)
# Requirement already satisfied: urllib3>=1.26.0 in c:\programdata\anaconda3\lib\site-packages (from spotipy) (1.26.7)
# Collecting async-timeout>=4.0.3
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.2)
# Installing collected packages: async-timeout, redis, spotipy
# Successfully installed async-timeout-4.0.3 redis-5.0.8 spotipy-2.24.0

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credential_manager = SpotifyClientCredentials(client_id = '21dda2c0b24a49bcb4de9af0f00d8e63', client_secret = 'cb8dc39b49e84225b459ea1d052f686e')

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credential_manager)

# %%
playlist_link = 'https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF'

# %%
playlist_url = playlist_link.split('/')[-1]

# %%
data = sp.playlist_tracks(playlist_url)

# %%
len(data['items'])
# Out:
# 50

# %%
data['items'][0]['track']['album']
# Out:
# {'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'type': 'album',
#  'album_type': 'single',
#  'href': 'https://api.spotify.com/v1/albums/10FLjwfpbxLmW8c25Xyc2N',
#  'id': '10FLjwfpbxLmW8c25Xyc2N',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b27382ea2e9e1858aa012c57cd45',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e0282ea2e9e1858aa012c57cd45',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d0000485182ea2e9e1858aa012c57cd45',
#    'width': 64}],
#  'name': 'Die With A Smile',
#  'release_date': '2024-08-16',
#  'release_date_precision': 'day',
#  'uri': 'spotify:album:10FLjwfpbxLmW8c25Xyc2N',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#    'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#    'id': '1HY2Jd0NmPuamShAr6KMms',
#    'name': 'Lady Gaga',
#    'type': 'artist',
#    'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#    'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#    'id': '0du5cEVh5yTK9QJze8zA0C',
#    'name': 'Bruno Mars',
#    'type': 'artist',
#    'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'},
#  'total_tracks': 1}

# %%
data['items'][0]['track']['album']['id']
# Out:
# '10FLjwfpbxLmW8c25Xyc2N'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Die With A Smile'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2024-08-16'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    release_date = row['track']['album']['release_date']
    total_track = row['track']['album']['total_tracks']
    url = row['track']['album']['external_urls']['spotify']
    
    album_element = {'album_id': album_id, 'album_name': album_name, 'release_date': release_date, 'total_track': total_track, 'url': url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '10FLjwfpbxLmW8c25Xyc2N',
#   'album_name': 'Die With A Smile',
#   'release_date': '2024-08-16',
#   'total_track': 1,
#   'url': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'album_name': 'HIT ME HARD AND SOFT',
#   'release_date': '2024-05-17',
#   'total_track': 10,
#   'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'album_name': "Short n' Sweet",
#   'release_date': '2024-08-23',
#   'total_track': 12,
#   'url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
#  {'album_id': '15XcLhiVMlSOipUddTNDnr',
#   'album_name': 'MUSE',
#   'release_date': '2024-07-19',
#   'total_track': 7,
#   'url': 'https://open.spotify.com/album/15XcLhiVMlSOipUddTNDnr'},
#  {'album_id': '5quMTd5zeI9yW5UDua8wS4',
#   'album_name': 'Espresso',
#   'release_date': '2024-04-12',
#   'total_track': 1,
#   'url': 'https://open.spotify.com/album/5quMTd5zeI9yW5UDua8wS4'},
#  {'album_id': '6W0Gabv5f3ugnckc6YgfJQ',
#   'album_name': 'The Emptiness Machine',
#   'release_date': '2024-09-05',
#   'total_track': 1,
#   'url': 'https://open.spotify.com/album/6W0Gabv5f3ugnckc6YgfJQ'},
#  {'album_id': '5bBaoign62r1i7OV8w7mi9',
#   'album_name': 'Please Please Please',
#   'release_date': '2024-06-06',
#   'total_track': 2,
#   'url': 'https://open.spotify.com/album/5bBaoign62r1i7OV8w7mi9'},
#  {'album_id': '5ylbxH7EqpsmHZCRuiYewS',
#   'album_name': 'Si Antes Te Hubiera Conocido',
#   'release_date': '2024-06-21',
#   'total_track': 1,
#   'url': 'https://open.spotify.com/album/5ylbxH7EqpsmHZCRuiYewS'},
#  {'album_id': '1WAjjRMfZjEXtB0lQrAw6Q',
#   'album_name': 'Good Luck, Babe!',
#   'release_date': '2024-04-05',
#   'total_track': 1,
#   'url': 'https://open.spotify.com/album/1WAjjRMfZjEXtB0lQrAw6Q'},
#  {'album_id': '168CdR21lfn0TTyw1Pkdcm',
#   'album_name': 'Fireworks & Rollerblades',
#   'release_date': '2024-04-05',
#   'total_track': 15,
#   'url': 'https://open.spotify.com/album/168CdR21lfn0TTyw1Pkdcm'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'album_name': "Short n' Sweet",
#   'release_date': '2024-08-23',
#   'total_track': 12,
#   'url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
#  {'album_id': '0DLvFVIfwt3OHdK9kGeEM3',
#   'album_name': "Where I've Been, Isn't Where I'm Going",
#   'release_date': '2024-05-31',
#   'total_track': 12,
#   'url': 'https://open.spotify.com/album/0DLvFVIfwt3OHdK9kGeEM3'},
#  {'album_id': '3P4SQqMMgjqfqVxgLwtYRk',
#   'album_name': 'Unreal Unearth: Unheard',
#   'release_date': '2024-03-22',
#   'total_track': 20,
#   'url': 'https://open.spotify.com/album/3P4SQqMMgjqfqVxgLwtYRk'},
#  {'album_id': '7nacKlk586eLRBSIsrk9DB',
#   'album_name': "I've Tried Everything But Therapy (Part 1)",
#   'release_date': '2023-09-15',
#   'total_track': 10,
#   'url': 'https://open.spotify.com/album/7nacKlk586eLRBSIsrk9DB'},
#  {'album_id': '0Wmt50XH9EZvSuML0t1hlb',
#   'album_name': 'Neva Play (feat. RM of BTS)',
#   'release_date': '2024-09-06',
#   'total_track': 1,
#   'url': 'https://open.spotify.com/album/0Wmt50XH9EZvSuML0t1hlb'},
#  {'album_id': '6Yw4204wbgmpsGTzjXBhYD',
#   'album_name': 'Big Dawgs',
#   'release_date': '2024-07-09',
#   'total_track': 1,
#   'url': 'https://open.spotify.com/album/6Yw4204wbgmpsGTzjXBhYD'},
#  {'album_id': '3rQE6GuZuvLF82h0o3Xqqd',
#   'album_name': 'Guess featuring Billie Eilish',
#   'release_date': '2024-08-01',
#   'total_track': 1,
#   'url': 'https://open.spotify.com/album/3rQE6GuZuvLF82h0o3Xqqd'},
#  {'album_id': '4BbsHmXEghoPPevQjPnHXx',
#   'album_name': 'F-1 Trillion',
#   'release_date': '2024-08-15',
#   'total_track': 18,
#   'url': 'https://open.spotify.com/album/4BbsHmXEghoPPevQjPnHXx'},
#  {'album_id': '6MikZBKCtKfPM4439yzBRz',
#   'album_name': 'EL COMIENZO',
#   'release_date': '2024-08-09',
#   'total_track': 7,
#   'url': 'https://open.spotify.com/album/6MikZBKCtKfPM4439yzBRz'},
#  {'album_id': '7tzVd1fwkxsorytCBjEJkU',
#   'album_name': 'The Idol Episode 4 - Music from the HBO Original Series',
#   'release_date': '2023-06-23',
#   'total_track': 3,
#   'url': 'https://open.spotify.com/album/7tzVd1fwkxsorytCBjEJkU'},
#  {'album_id': '5JjnoGJyOxfSZUZtk2rRwZ',
#   'album_name': 'Not Like Us',
#   'release_date': '2024-05-04',
#   'total_track': 1,
#   'url': 'https://open.spotify.com/album/5JjnoGJyOxfSZUZtk2rRwZ'},
#  {'album_id': '4xkM0BwLM9H2IUcbYzpcBI',
#   'album_name': 'I Love You.',
#   'release_date': '2013-04-19',
#   'total_track': 11,
#   'url': 'https://open.spotify.com/album/4xkM0BwLM9H2IUcbYzpcBI'},
#  {'album_id': '5H7sO778w4hgr2v2600ajN',
#   'album_name': 'UWAIE',
#   'release_date': '2024-08-15',
#   'total_track': 1,
#   'url': 'https://open.spotify.com/album/5H7sO778w4hgr2v2600ajN'},
#  {'album_id': '20RMokVwJ2wjQ0s8FOdOFC',
#   'album_name': 'No Strings Attached',
#   'release_date': '2000-03-21',
#   'total_track': 12,
#   'url': 'https://open.spotify.com/album/20RMokVwJ2wjQ0s8FOdOFC'},
#  {'album_id': '2Z1gnUf3nbn6DtwZSUIH54',
#   'album_name': 'MILLION DOLLAR BABY',
#   'release_date': '2024-04-26',
#   'total_track': 2,
#   'url': 'https://open.spotify.com/album/2Z1gnUf3nbn6DtwZSUIH54'},
#  {'album_id': '4sD1qg4jwTZR4mvR4Iflk5',
#   'album_name': 'Strange Trails',
#   'release_date': '2015-04-06',
#   'total_track': 14,
#   'url': 'https://open.spotify.com/album/4sD1qg4jwTZR4mvR4Iflk5'},
#  {'album_id': '78bpIziExqiI9qztvNFlQu',
#   'album_name': 'AM',
#   'release_date': '2013-09-09',
#   'total_track': 12,
#   'url': 'https://open.spotify.com/album/78bpIziExqiI9qztvNFlQu'},
#  {'album_id': '5EYKrEDnKhhcNxGedaRQeK',
#   'album_name': 'eternal sunshine',
#   'release_date': '2024-03-08',
#   'total_track': 13,
#   'url': 'https://open.spotify.com/album/5EYKrEDnKhhcNxGedaRQeK'},
#  {'album_id': '4Gfnly5CzMJQqkUFfoHaP3',
#   'album_name': 'Meteora',
#   'release_date': '2003-09-16',
#   'total_track': 13,
#   'url': 'https://open.spotify.com/album/4Gfnly5CzMJQqkUFfoHaP3'},
#  {'album_id': '0EiI8ylL0FmWWpgHVTsZjZ',
#   'album_name': 'The Rise and Fall of a Midwest Princess',
#   'release_date': '2023-09-22',
#   'total_track': 14,
#   'url': 'https://open.spotify.com/album/0EiI8ylL0FmWWpgHVTsZjZ'},
#  {'album_id': '4M8ThNHbNjda2cPwL8XZHS',
#   'album_name': 'Move',
#   'release_date': '2024-06-07',
#   'total_track': 1,
#   'url': 'https://open.spotify.com/album/4M8ThNHbNjda2cPwL8XZHS'},
#  {'album_id': '6ZG5lRT77aJ3btmArcykra',
#   'album_name': 'Parachutes',
#   'release_date': '2000-07-10',
#   'total_track': 10,
#   'url': 'https://open.spotify.com/album/6ZG5lRT77aJ3btmArcykra'},
#  {'album_id': '2ha4ucrONN0cihLMkP02Ch',
#   'album_name': 'New Woman (feat. ROSALÍA)',
#   'release_date': '2024-08-15',
#   'total_track': 1,
#   'url': 'https://open.spotify.com/album/2ha4ucrONN0cihLMkP02Ch'},
#  {'album_id': '4JDXBZdRPId4devseaAOKH',
#   'album_name': 'DECIDE',
#   'release_date': '2022-09-16',
#   'total_track': 13,
#   'url': 'https://open.spotify.com/album/4JDXBZdRPId4devseaAOKH'},
#  {'album_id': '40HsqPqeSR9Xe3IyAJWr6e',
#   'album_name': 'What Happens Now?',
#   'release_date': '2024-02-16',
#   'total_track': 8,
#   'url': 'https://open.spotify.com/album/40HsqPqeSR9Xe3IyAJWr6e'},
#  {'album_id': '5nzSCZ7NhKvAysI0tmNOdD',
#   'album_name': 'yustyna',
#   'release_date': '2024-07-11',
#   'total_track': 14,
#   'url': 'https://open.spotify.com/album/5nzSCZ7NhKvAysI0tmNOdD'},
#  {'album_id': '1NAmidJlEaVgA3MpcPFYGq',
#   'album_name': 'Lover',
#   'release_date': '2019-08-23',
#   'total_track': 18,
#   'url': 'https://open.spotify.com/album/1NAmidJlEaVgA3MpcPFYGq'},
#  {'album_id': '2m0euKZUDcoyEXHIS5MFCq',
#   'album_name': 'Alibi (with Pabllo Vittar & Yseult)',
#   'release_date': '2024-06-28',
#   'total_track': 1,
#   'url': 'https://open.spotify.com/album/2m0euKZUDcoyEXHIS5MFCq'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'album_name': 'HIT ME HARD AND SOFT',
#   'release_date': '2024-05-17',
#   'total_track': 10,
#   'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '3VNxRarx9HUI5w7DHv0TBj',
#   'album_name': 'Stargazing',
#   'release_date': '2024-05-10',
#   'total_track': 1,
#   'url': 'https://open.spotify.com/album/3VNxRarx9HUI5w7DHv0TBj'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'album_name': "Short n' Sweet",
#   'release_date': '2024-08-23',
#   'total_track': 12,
#   'url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
#  {'album_id': '56bdWeO40o3WfAD2Lja4dl',
#   'album_name': 'The Secret of Us',
#   'release_date': '2024-06-21',
#   'total_track': 13,
#   'url': 'https://open.spotify.com/album/56bdWeO40o3WfAD2Lja4dl'},
#  {'album_id': '18NOKLkZETa4sWwLMIm0UZ',
#   'album_name': 'UTOPIA',
#   'release_date': '2023-07-28',
#   'total_track': 19,
#   'url': 'https://open.spotify.com/album/18NOKLkZETa4sWwLMIm0UZ'},
#  {'album_id': '0lgs2Sa82lyX89nBUWyUy6',
#   'album_name': 'FERXXOCALIPSIS',
#   'release_date': '2023-12-01',
#   'total_track': 10,
#   'url': 'https://open.spotify.com/album/0lgs2Sa82lyX89nBUWyUy6'},
#  {'album_id': '6MikZBKCtKfPM4439yzBRz',
#   'album_name': 'EL COMIENZO',
#   'release_date': '2024-08-09',
#   'total_track': 7,
#   'url': 'https://open.spotify.com/album/6MikZBKCtKfPM4439yzBRz'},
#  {'album_id': '4DWrYvfGXRE8ko5ZxlIpit',
#   'album_name': 'Sailor Song',
#   'release_date': '2024-07-26',
#   'total_track': 1,
#   'url': 'https://open.spotify.com/album/4DWrYvfGXRE8ko5ZxlIpit'},
#  {'album_id': '4UMjBXcRqIgMZ1XumU2x5T',
#   'album_name': 'Dizzy up the Girl',
#   'release_date': '1998',
#   'total_track': 13,
#   'url': 'https://open.spotify.com/album/4UMjBXcRqIgMZ1XumU2x5T'},
#  {'album_id': '5kvw1bAOvzJdNi4hdgfaNf',
#   'album_name': 'ÉXODO',
#   'release_date': '2024-06-20',
#   'total_track': 24,
#   'url': 'https://open.spotify.com/album/5kvw1bAOvzJdNi4hdgfaNf'},
#  {'album_id': '00ESTj1vBUkIbaTHaXaXu3',
#   'album_name': 'SE ME OLVIDA',
#   'release_date': '2024-08-23',
#   'total_track': 1,
#   'url': 'https://open.spotify.com/album/00ESTj1vBUkIbaTHaXaXu3'},
#  {'album_id': '2nkto6YNI4rUYTLqEwWJ3o',
#   'album_name': 'Flower Boy',
#   'release_date': '2017-07-21',
#   'total_track': 14,
#   'url': 'https://open.spotify.com/album/2nkto6YNI4rUYTLqEwWJ3o'}]

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#   'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#   'id': '0du5cEVh5yTK9QJze8zA0C',
#   'name': 'Bruno Mars',
#   'type': 'artist',
#   'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}]

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_id = artist['id']
                artist_name = artist['name']
                artist_url = artist['external_urls']['spotify']
                
                artist_element = {'artist_id': artist_id, 'artist_name': artist_name, 'artist_url': artist_url}
                artist_list.append(artist_element)

# %%
artist_list
# Out:
# [{'artist_id': '1HY2Jd0NmPuamShAr6KMms',
#   'artist_name': 'Lady Gaga',
#   'artist_url': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'artist_url': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'artist_url': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'artist_url': 'https://open.spotify.com/artist/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '1oSPZhvZMIrWW5I41kPkkY',
#   'artist_name': 'Jimin',
#   'artist_url': 'https://open.spotify.com/artist/1oSPZhvZMIrWW5I41kPkkY'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'artist_url': 'https://open.spotify.com/artist/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '6XyY86QOPPrYVGvF9ch6wz',
#   'artist_name': 'Linkin Park',
#   'artist_url': 'https://open.spotify.com/artist/6XyY86QOPPrYVGvF9ch6wz'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'artist_url': 'https://open.spotify.com/artist/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '790FomKkXshlbRYZFtlgla',
#   'artist_name': 'KAROL G',
#   'artist_url': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#  {'artist_id': '7GlBOeep6PqTfFi59PTUUN',
#   'artist_name': 'Chappell Roan',
#   'artist_url': 'https://open.spotify.com/artist/7GlBOeep6PqTfFi59PTUUN'},
#  {'artist_id': '22wbnEMDvgVIAGdFeek6ET',
#   'artist_name': 'Benson Boone',
#   'artist_url': 'https://open.spotify.com/artist/22wbnEMDvgVIAGdFeek6ET'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'artist_url': 'https://open.spotify.com/artist/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '3y2cIKLjiOlp1Np37WiUdH',
#   'artist_name': 'Shaboozey',
#   'artist_url': 'https://open.spotify.com/artist/3y2cIKLjiOlp1Np37WiUdH'},
#  {'artist_id': '2FXC3k01G6Gw61bmprjgqS',
#   'artist_name': 'Hozier',
#   'artist_url': 'https://open.spotify.com/artist/2FXC3k01G6Gw61bmprjgqS'},
#  {'artist_id': '33qOK5uJ8AR2xuQQAhHump',
#   'artist_name': 'Teddy Swims',
#   'artist_url': 'https://open.spotify.com/artist/33qOK5uJ8AR2xuQQAhHump'},
#  {'artist_id': '181bsRPaVXVlUKXrxwZfHK',
#   'artist_name': 'Megan Thee Stallion',
#   'artist_url': 'https://open.spotify.com/artist/181bsRPaVXVlUKXrxwZfHK'},
#  {'artist_id': '2auC28zjQyVTsiZKNgPRGs',
#   'artist_name': 'RM',
#   'artist_url': 'https://open.spotify.com/artist/2auC28zjQyVTsiZKNgPRGs'},
#  {'artist_id': '4nVa6XlBFlIkF6msW57PHp',
#   'artist_name': 'Hanumankind',
#   'artist_url': 'https://open.spotify.com/artist/4nVa6XlBFlIkF6msW57PHp'},
#  {'artist_id': '6tYCSHLtTI54AQJFOMfU45',
#   'artist_name': 'Kalmi',
#   'artist_url': 'https://open.spotify.com/artist/6tYCSHLtTI54AQJFOMfU45'},
#  {'artist_id': '25uiPmTg16RbhZWAqwLBy5',
#   'artist_name': 'Charli xcx',
#   'artist_url': 'https://open.spotify.com/artist/25uiPmTg16RbhZWAqwLBy5'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'artist_url': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '246dkjvS1zLTtiykXe5h60',
#   'artist_name': 'Post Malone',
#   'artist_url': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#  {'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'artist_url': 'https://open.spotify.com/artist/4oUHIQIBe0LHzYfvXNW4QM'},
#  {'artist_id': '7CvTknweLr9feJtRGrpDBy',
#   'artist_name': 'FloyyMenor',
#   'artist_url': 'https://open.spotify.com/artist/7CvTknweLr9feJtRGrpDBy'},
#  {'artist_id': '1Yj5Xey7kTwvZla8sqdsdE',
#   'artist_name': 'Cris Mj',
#   'artist_url': 'https://open.spotify.com/artist/1Yj5Xey7kTwvZla8sqdsdE'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'artist_url': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '250b0Wlc5Vk0CoUsaCY84M',
#   'artist_name': 'JENNIE',
#   'artist_url': 'https://open.spotify.com/artist/250b0Wlc5Vk0CoUsaCY84M'},
#  {'artist_id': '1pBLC0qVRTB5zVMuteQ9jJ',
#   'artist_name': 'Lily-Rose Depp',
#   'artist_url': 'https://open.spotify.com/artist/1pBLC0qVRTB5zVMuteQ9jJ'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'artist_url': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '77SW9BnxLY8rJ0RciFqkHh',
#   'artist_name': 'The Neighbourhood',
#   'artist_url': 'https://open.spotify.com/artist/77SW9BnxLY8rJ0RciFqkHh'},
#  {'artist_id': '3UTF2no3muGdiFXVujl94i',
#   'artist_name': 'Kapo',
#   'artist_url': 'https://open.spotify.com/artist/3UTF2no3muGdiFXVujl94i'},
#  {'artist_id': '6Ff53KvcvAj5U7Z1vojB5o',
#   'artist_name': '*NSYNC',
#   'artist_url': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#  {'artist_id': '1WaFQSHVGZQJTbf0BdxdNo',
#   'artist_name': 'Tommy Richman',
#   'artist_url': 'https://open.spotify.com/artist/1WaFQSHVGZQJTbf0BdxdNo'},
#  {'artist_id': '6ltzsmQQbmdoHHbLZ4ZN25',
#   'artist_name': 'Lord Huron',
#   'artist_url': 'https://open.spotify.com/artist/6ltzsmQQbmdoHHbLZ4ZN25'},
#  {'artist_id': '7Ln80lUS6He07XvHI8qqHH',
#   'artist_name': 'Arctic Monkeys',
#   'artist_url': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#  {'artist_id': '66CXWjxzNUsdJxJ2JdwvnR',
#   'artist_name': 'Ariana Grande',
#   'artist_url': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#  {'artist_id': '6XyY86QOPPrYVGvF9ch6wz',
#   'artist_name': 'Linkin Park',
#   'artist_url': 'https://open.spotify.com/artist/6XyY86QOPPrYVGvF9ch6wz'},
#  {'artist_id': '7GlBOeep6PqTfFi59PTUUN',
#   'artist_name': 'Chappell Roan',
#   'artist_url': 'https://open.spotify.com/artist/7GlBOeep6PqTfFi59PTUUN'},
#  {'artist_id': '2loEsOijJ6XiGzWYFXMIRk',
#   'artist_name': 'Adam Port',
#   'artist_url': 'https://open.spotify.com/artist/2loEsOijJ6XiGzWYFXMIRk'},
#  {'artist_id': '6XjgqvaVLUib6lCerbZrYD',
#   'artist_name': 'Stryv',
#   'artist_url': 'https://open.spotify.com/artist/6XjgqvaVLUib6lCerbZrYD'},
#  {'artist_id': '26WKgv73kRHD0gEDKD1i8j',
#   'artist_name': 'Keinemusik',
#   'artist_url': 'https://open.spotify.com/artist/26WKgv73kRHD0gEDKD1i8j'},
#  {'artist_id': '2yyaNPcdxZcn4iutCcLMaC',
#   'artist_name': 'Orso',
#   'artist_url': 'https://open.spotify.com/artist/2yyaNPcdxZcn4iutCcLMaC'},
#  {'artist_id': '37lTKHi901VnwngQ7C8noT',
#   'artist_name': 'Malachiii',
#   'artist_url': 'https://open.spotify.com/artist/37lTKHi901VnwngQ7C8noT'},
#  {'artist_id': '4gzpq5DPGxSnKTe4SA8HAU',
#   'artist_name': 'Coldplay',
#   'artist_url': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#  {'artist_id': '5L1lO4eRHmJ7a0Q6csE5cT',
#   'artist_name': 'LISA',
#   'artist_url': 'https://open.spotify.com/artist/5L1lO4eRHmJ7a0Q6csE5cT'},
#  {'artist_id': '7ltDVBr6mKbRvohxheJ9h1',
#   'artist_name': 'ROSALÍA',
#   'artist_url': 'https://open.spotify.com/artist/7ltDVBr6mKbRvohxheJ9h1'},
#  {'artist_id': '5p9HO3XC5P3BLxJs5Mtrhm',
#   'artist_name': 'Djo',
#   'artist_url': 'https://open.spotify.com/artist/5p9HO3XC5P3BLxJs5Mtrhm'},
#  {'artist_id': '7Ez6lTtSMjMf2YSYpukP1I',
#   'artist_name': 'Dasha',
#   'artist_url': 'https://open.spotify.com/artist/7Ez6lTtSMjMf2YSYpukP1I'},
#  {'artist_id': '0PCCGZ0wGLizHt2KZ7hhA2',
#   'artist_name': 'Artemas',
#   'artist_url': 'https://open.spotify.com/artist/0PCCGZ0wGLizHt2KZ7hhA2'},
#  {'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'artist_name': 'Taylor Swift',
#   'artist_url': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_id': '5MraexJKZDrQYzS98kNwie',
#   'artist_name': 'Sevdaliza',
#   'artist_url': 'https://open.spotify.com/artist/5MraexJKZDrQYzS98kNwie'},
#  {'artist_id': '6tzRZ39aZlNqlUzQlkuhDV',
#   'artist_name': 'Pabllo Vittar',
#   'artist_url': 'https://open.spotify.com/artist/6tzRZ39aZlNqlUzQlkuhDV'},
#  {'artist_id': '1QsdzIKkTT5gDFj8GB1cIX',
#   'artist_name': 'Yseult',
#   'artist_url': 'https://open.spotify.com/artist/1QsdzIKkTT5gDFj8GB1cIX'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'artist_url': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '3bO19AOone0ubCsfDXDtYt',
#   'artist_name': 'Myles Smith',
#   'artist_url': 'https://open.spotify.com/artist/3bO19AOone0ubCsfDXDtYt'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'artist_url': 'https://open.spotify.com/artist/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '4tuJ0bMpJh08umKkEXKUI5',
#   'artist_name': 'Gracie Abrams',
#   'artist_url': 'https://open.spotify.com/artist/4tuJ0bMpJh08umKkEXKUI5'},
#  {'artist_id': '0Y5tJX1MQlPlqiwlOH1tJY',
#   'artist_name': 'Travis Scott',
#   'artist_url': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#  {'artist_id': '699OTQXzgjhIYAHMy9RyPD',
#   'artist_name': 'Playboi Carti',
#   'artist_url': 'https://open.spotify.com/artist/699OTQXzgjhIYAHMy9RyPD'},
#  {'artist_id': '2LRoIwlKmHjgvigdNGBHNo',
#   'artist_name': 'Feid',
#   'artist_url': 'https://open.spotify.com/artist/2LRoIwlKmHjgvigdNGBHNo'},
#  {'artist_id': '7jAs1uPnpfNmT6e5qtEPxq',
#   'artist_name': 'ATL Jacob',
#   'artist_url': 'https://open.spotify.com/artist/7jAs1uPnpfNmT6e5qtEPxq'},
#  {'artist_id': '7CvTknweLr9feJtRGrpDBy',
#   'artist_name': 'FloyyMenor',
#   'artist_url': 'https://open.spotify.com/artist/7CvTknweLr9feJtRGrpDBy'},
#  {'artist_id': '1iCnM8foFssWlPRLfAbIwo',
#   'artist_name': 'Gigi Perez',
#   'artist_url': 'https://open.spotify.com/artist/1iCnM8foFssWlPRLfAbIwo'},
#  {'artist_id': '2sil8z5kiy4r76CRTXxBCA',
#   'artist_name': 'The Goo Goo Dolls',
#   'artist_url': 'https://open.spotify.com/artist/2sil8z5kiy4r76CRTXxBCA'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'artist_url': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '6pV5zH2LzjOUHaAvENdMMa',
#   'artist_name': 'Neton Vega',
#   'artist_url': 'https://open.spotify.com/artist/6pV5zH2LzjOUHaAvENdMMa'},
#  {'artist_id': '6B1hSmaLdOvChinK2Z7gfi',
#   'artist_name': 'Maisak',
#   'artist_url': 'https://open.spotify.com/artist/6B1hSmaLdOvChinK2Z7gfi'},
#  {'artist_id': '2LRoIwlKmHjgvigdNGBHNo',
#   'artist_name': 'Feid',
#   'artist_url': 'https://open.spotify.com/artist/2LRoIwlKmHjgvigdNGBHNo'},
#  {'artist_id': '4V8LLVI7PbaPR0K2TGSxFF',
#   'artist_name': 'Tyler, The Creator',
#   'artist_url': 'https://open.spotify.com/artist/4V8LLVI7PbaPR0K2TGSxFF'},
#  {'artist_id': '1U1el3k54VvEUzo3ybLPlM',
#   'artist_name': 'Kali Uchis',
#   'artist_url': 'https://open.spotify.com/artist/1U1el3k54VvEUzo3ybLPlM'}]

# %%
data['items'][0]['track']['id']
# Out:
# '2plbrEY59IikOBgBGLjaoe'

# %%
data['items'][0]['track']
# Out:
# {'preview_url': None,
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'explicit': False,
#  'type': 'track',
#  'episode': False,
#  'track': True,
#  'album': {'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'type': 'album',
#   'album_type': 'single',
#   'href': 'https://api.spotify.com/v1/albums/10FLjwfpbxLmW8c25Xyc2N',
#   'id': '10FLjwfpbxLmW8c25Xyc2N',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27382ea2e9e1858aa012c57cd45',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0282ea2e9e1858aa012c57cd45',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485182ea2e9e1858aa012c57cd45',
#     'width': 64}],
#   'name': 'Die With A Smile',
#   'release_date': '2024-08-16',
#   'release_date_precision': 'day',
#   'uri': 'spotify:album:10FLjwfpbxLmW8c25Xyc2N',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#     'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#     'id': '0du5cEVh5yTK9QJze8zA0C',
#     'name': 'Bruno Mars',
#     'type': 'artist',
#     'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'},
#   'total_tracks': 1},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#    'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#    'id': '1HY2Jd0NmPuamShAr6KMms',
#    'name': 'Lady Gaga',
#    'type': 'artist',
#    'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#    'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#    'id': '0du5cEVh5yTK9QJze8zA0C',
#    'name': 'Bruno Mars',
#    'type': 'artist',
#    'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#  'disc_number': 1,
#  'track_number': 1,
#  'duration_ms': 251667,
#  'external_ids': {'isrc': 'USUM72409273'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/2plbrEY59IikOBgBGLjaoe'},
#  'href': 'https://api.spotify.com/v1/tracks/2plbrEY59IikOBgBGLjaoe',
#  'id': '2plbrEY59IikOBgBGLjaoe',
#  'name': 'Die With A Smile',
#  'popularity': 98,
#  'uri': 'spotify:track:2plbrEY59IikOBgBGLjaoe',
#  'is_local': False}

# %%
data['items'][0]['track']['name']
# Out:
# 'Die With A Smile'

# %%
data['items'][0]['track']['duration_ms']
# Out:
# 251667

# %%
data['items'][0]['track']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/track/2plbrEY59IikOBgBGLjaoe'

# %%
data['items'][0]['track']['popularity']
# Out:
# 98

# %%
data['items'][0]['added_at']
# Out:
# '2024-09-13T13:10:58Z'

# %%
data['items'][0]['track']['album']['id']
# Out:
# '10FLjwfpbxLmW8c25Xyc2N'

# %%
data['items'][0]['track']['artists'][0]['id']
# Out:
# '1HY2Jd0NmPuamShAr6KMms'

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_popularity = row['track']['popularity']
    song_url = row['track']['external_urls']['spotify']
    song_added_at = row['added_at']
    song_album_id = row['track']['album']['id']
    song_artist_id = row['track']['artists'][0]['id']
    
    song_element = {
        'song_id': song_id,
        'song_name': song_name,
        'song_duration': song_duration,
        'song_popularity': song_popularity,
        'song_url': song_url,
        'song_added_at': song_added_at,
        'song_album_id': song_album_id,
        'song_artist_id': song_artist_id
    }
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '2plbrEY59IikOBgBGLjaoe',
#   'song_name': 'Die With A Smile',
#   'song_duration': 251667,
#   'song_popularity': 98,
#   'song_url': 'https://open.spotify.com/track/2plbrEY59IikOBgBGLjaoe',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '10FLjwfpbxLmW8c25Xyc2N',
#   'song_artist_id': '1HY2Jd0NmPuamShAr6KMms'},
#  {'song_id': '6dOtVTDdiauQNBQEDOtlAB',
#   'song_name': 'BIRDS OF A FEATHER',
#   'song_duration': 210373,
#   'song_popularity': 100,
#   'song_url': 'https://open.spotify.com/track/6dOtVTDdiauQNBQEDOtlAB',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'song_artist_id': '6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'song_id': '5G2f63n7IPVPPjfNIGih7Q',
#   'song_name': 'Taste',
#   'song_duration': 157279,
#   'song_popularity': 95,
#   'song_url': 'https://open.spotify.com/track/5G2f63n7IPVPPjfNIGih7Q',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'song_artist_id': '74KM79TiuVKeVCqs8QtB0B'},
#  {'song_id': '7tI8dRuH2Yc6RuoTjxo4dU',
#   'song_name': 'Who',
#   'song_duration': 170887,
#   'song_popularity': 94,
#   'song_url': 'https://open.spotify.com/track/7tI8dRuH2Yc6RuoTjxo4dU',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '15XcLhiVMlSOipUddTNDnr',
#   'song_artist_id': '1oSPZhvZMIrWW5I41kPkkY'},
#  {'song_id': '2qSkIjg1o9h3YT9RAgYN75',
#   'song_name': 'Espresso',
#   'song_duration': 175459,
#   'song_popularity': 97,
#   'song_url': 'https://open.spotify.com/track/2qSkIjg1o9h3YT9RAgYN75',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '5quMTd5zeI9yW5UDua8wS4',
#   'song_artist_id': '74KM79TiuVKeVCqs8QtB0B'},
#  {'song_id': '2PnlsTsOTLE5jnBnNe2K0A',
#   'song_name': 'The Emptiness Machine',
#   'song_duration': 190427,
#   'song_popularity': 90,
#   'song_url': 'https://open.spotify.com/track/2PnlsTsOTLE5jnBnNe2K0A',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '6W0Gabv5f3ugnckc6YgfJQ',
#   'song_artist_id': '6XyY86QOPPrYVGvF9ch6wz'},
#  {'song_id': '5N3hjp1WNayUPZrA8kJmJP',
#   'song_name': 'Please Please Please',
#   'song_duration': 186365,
#   'song_popularity': 96,
#   'song_url': 'https://open.spotify.com/track/5N3hjp1WNayUPZrA8kJmJP',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '5bBaoign62r1i7OV8w7mi9',
#   'song_artist_id': '74KM79TiuVKeVCqs8QtB0B'},
#  {'song_id': '6WatFBLVB0x077xWeoVc2k',
#   'song_name': 'Si Antes Te Hubiera Conocido',
#   'song_duration': 195824,
#   'song_popularity': 96,
#   'song_url': 'https://open.spotify.com/track/6WatFBLVB0x077xWeoVc2k',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '5ylbxH7EqpsmHZCRuiYewS',
#   'song_artist_id': '790FomKkXshlbRYZFtlgla'},
#  {'song_id': '0WbMK4wrZ1wFSty9F7FCgu',
#   'song_name': 'Good Luck, Babe!',
#   'song_duration': 218423,
#   'song_popularity': 97,
#   'song_url': 'https://open.spotify.com/track/0WbMK4wrZ1wFSty9F7FCgu',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '1WAjjRMfZjEXtB0lQrAw6Q',
#   'song_artist_id': '7GlBOeep6PqTfFi59PTUUN'},
#  {'song_id': '3xkHsmpQCBMytMJNiDf3Ii',
#   'song_name': 'Beautiful Things',
#   'song_duration': 180304,
#   'song_popularity': 91,
#   'song_url': 'https://open.spotify.com/track/3xkHsmpQCBMytMJNiDf3Ii',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '168CdR21lfn0TTyw1Pkdcm',
#   'song_artist_id': '22wbnEMDvgVIAGdFeek6ET'},
#  {'song_id': '1UHS8Rf6h5Ar3CDWRd3wjF',
#   'song_name': 'Bed Chem',
#   'song_duration': 171869,
#   'song_popularity': 91,
#   'song_url': 'https://open.spotify.com/track/1UHS8Rf6h5Ar3CDWRd3wjF',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'song_artist_id': '74KM79TiuVKeVCqs8QtB0B'},
#  {'song_id': '5fZJQrFKWQLb7FpJXZ1g7K',
#   'song_name': 'A Bar Song (Tipsy)',
#   'song_duration': 171291,
#   'song_popularity': 87,
#   'song_url': 'https://open.spotify.com/track/5fZJQrFKWQLb7FpJXZ1g7K',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '0DLvFVIfwt3OHdK9kGeEM3',
#   'song_artist_id': '3y2cIKLjiOlp1Np37WiUdH'},
#  {'song_id': '5Z0UnEtpLDQyYlWwgi8m9C',
#   'song_name': 'Too Sweet',
#   'song_duration': 251424,
#   'song_popularity': 88,
#   'song_url': 'https://open.spotify.com/track/5Z0UnEtpLDQyYlWwgi8m9C',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '3P4SQqMMgjqfqVxgLwtYRk',
#   'song_artist_id': '2FXC3k01G6Gw61bmprjgqS'},
#  {'song_id': '17phhZDn6oGtzMe56NuWvj',
#   'song_name': 'Lose Control',
#   'song_duration': 210688,
#   'song_popularity': 91,
#   'song_url': 'https://open.spotify.com/track/17phhZDn6oGtzMe56NuWvj',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '7nacKlk586eLRBSIsrk9DB',
#   'song_artist_id': '33qOK5uJ8AR2xuQQAhHump'},
#  {'song_id': '2ZqTbIID9vFPTXaGyzbb4q',
#   'song_name': 'Neva Play (feat. RM of BTS)',
#   'song_duration': 157173,
#   'song_popularity': 85,
#   'song_url': 'https://open.spotify.com/track/2ZqTbIID9vFPTXaGyzbb4q',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '0Wmt50XH9EZvSuML0t1hlb',
#   'song_artist_id': '181bsRPaVXVlUKXrxwZfHK'},
#  {'song_id': '0OA00aPt3BV10qeMIs3meW',
#   'song_name': 'Big Dawgs',
#   'song_duration': 190666,
#   'song_popularity': 93,
#   'song_url': 'https://open.spotify.com/track/0OA00aPt3BV10qeMIs3meW',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '6Yw4204wbgmpsGTzjXBhYD',
#   'song_artist_id': '4nVa6XlBFlIkF6msW57PHp'},
#  {'song_id': '7qbJ4Dh8xuYUFdAWL8SFPK',
#   'song_name': 'Guess featuring Billie Eilish',
#   'song_duration': 143330,
#   'song_popularity': 75,
#   'song_url': 'https://open.spotify.com/track/7qbJ4Dh8xuYUFdAWL8SFPK',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '3rQE6GuZuvLF82h0o3Xqqd',
#   'song_artist_id': '25uiPmTg16RbhZWAqwLBy5'},
#  {'song_id': '5IZXB5IKAD2qlvTPJYDCFB',
#   'song_name': 'I Had Some Help (Feat. Morgan Wallen)',
#   'song_duration': 178205,
#   'song_popularity': 85,
#   'song_url': 'https://open.spotify.com/track/5IZXB5IKAD2qlvTPJYDCFB',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '4BbsHmXEghoPPevQjPnHXx',
#   'song_artist_id': '246dkjvS1zLTtiykXe5h60'},
#  {'song_id': '2esZG2XFtuoWWA9AfDvSxy',
#   'song_name': 'Gata Only',
#   'song_duration': 222000,
#   'song_popularity': 80,
#   'song_url': 'https://open.spotify.com/track/2esZG2XFtuoWWA9AfDvSxy',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '6MikZBKCtKfPM4439yzBRz',
#   'song_artist_id': '7CvTknweLr9feJtRGrpDBy'},
#  {'song_id': '7CyPwkp0oE8Ro9Dd5CUDjW',
#   'song_name': 'One Of The Girls (with JENNIE, Lily Rose Depp)',
#   'song_duration': 244684,
#   'song_popularity': 91,
#   'song_url': 'https://open.spotify.com/track/7CyPwkp0oE8Ro9Dd5CUDjW',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '7tzVd1fwkxsorytCBjEJkU',
#   'song_artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'song_id': '6AI3ezQ4o3HUoP6Dhudph3',
#   'song_name': 'Not Like Us',
#   'song_duration': 274192,
#   'song_popularity': 94,
#   'song_url': 'https://open.spotify.com/track/6AI3ezQ4o3HUoP6Dhudph3',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '5JjnoGJyOxfSZUZtk2rRwZ',
#   'song_artist_id': '2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'song_id': '2QjOHCTQ1Jl3zawyYOpxh6',
#   'song_name': 'Sweater Weather',
#   'song_duration': 240400,
#   'song_popularity': 91,
#   'song_url': 'https://open.spotify.com/track/2QjOHCTQ1Jl3zawyYOpxh6',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '4xkM0BwLM9H2IUcbYzpcBI',
#   'song_artist_id': '77SW9BnxLY8rJ0RciFqkHh'},
#  {'song_id': '5QjmUqgpPQgXgg4606DqZF',
#   'song_name': 'UWAIE',
#   'song_duration': 172427,
#   'song_popularity': 89,
#   'song_url': 'https://open.spotify.com/track/5QjmUqgpPQgXgg4606DqZF',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '5H7sO778w4hgr2v2600ajN',
#   'song_artist_id': '3UTF2no3muGdiFXVujl94i'},
#  {'song_id': '62bOmKYxYg7dhrC6gH9vFn',
#   'song_name': 'Bye Bye Bye - From Deadpool and Wolverine Soundtrack',
#   'song_duration': 200400,
#   'song_popularity': 90,
#   'song_url': 'https://open.spotify.com/track/62bOmKYxYg7dhrC6gH9vFn',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '20RMokVwJ2wjQ0s8FOdOFC',
#   'song_artist_id': '6Ff53KvcvAj5U7Z1vojB5o'},
#  {'song_id': '5AJ9hqTS2wcFQCELCFRO7A',
#   'song_name': 'MILLION DOLLAR BABY',
#   'song_duration': 155151,
#   'song_popularity': 93,
#   'song_url': 'https://open.spotify.com/track/5AJ9hqTS2wcFQCELCFRO7A',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '2Z1gnUf3nbn6DtwZSUIH54',
#   'song_artist_id': '1WaFQSHVGZQJTbf0BdxdNo'},
#  {'song_id': '3hRV0jL3vUpRrcy398teAU',
#   'song_name': 'The Night We Met',
#   'song_duration': 208211,
#   'song_popularity': 90,
#   'song_url': 'https://open.spotify.com/track/3hRV0jL3vUpRrcy398teAU',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '4sD1qg4jwTZR4mvR4Iflk5',
#   'song_artist_id': '6ltzsmQQbmdoHHbLZ4ZN25'},
#  {'song_id': '5XeFesFbtLpXzIVDNQP22n',
#   'song_name': 'I Wanna Be Yours',
#   'song_duration': 183956,
#   'song_popularity': 91,
#   'song_url': 'https://open.spotify.com/track/5XeFesFbtLpXzIVDNQP22n',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '78bpIziExqiI9qztvNFlQu',
#   'song_artist_id': '7Ln80lUS6He07XvHI8qqHH'},
#  {'song_id': '51ZQ1vr10ffzbwIjDCwqm4',
#   'song_name': "we can't be friends (wait for your love)",
#   'song_duration': 228639,
#   'song_popularity': 89,
#   'song_url': 'https://open.spotify.com/track/51ZQ1vr10ffzbwIjDCwqm4',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '5EYKrEDnKhhcNxGedaRQeK',
#   'song_artist_id': '66CXWjxzNUsdJxJ2JdwvnR'},
#  {'song_id': '2nLtzopw4rPReszdYBJU6h',
#   'song_name': 'Numb',
#   'song_duration': 187520,
#   'song_popularity': 88,
#   'song_url': 'https://open.spotify.com/track/2nLtzopw4rPReszdYBJU6h',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '4Gfnly5CzMJQqkUFfoHaP3',
#   'song_artist_id': '6XyY86QOPPrYVGvF9ch6wz'},
#  {'song_id': '4xdBrk0nFZaP54vvZj0yx7',
#   'song_name': 'HOT TO GO!',
#   'song_duration': 184841,
#   'song_popularity': 92,
#   'song_url': 'https://open.spotify.com/track/4xdBrk0nFZaP54vvZj0yx7',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '0EiI8ylL0FmWWpgHVTsZjZ',
#   'song_artist_id': '7GlBOeep6PqTfFi59PTUUN'},
#  {'song_id': '1BJJbSX6muJVF2AK7uH1x4',
#   'song_name': 'Move',
#   'song_duration': 177598,
#   'song_popularity': 91,
#   'song_url': 'https://open.spotify.com/track/1BJJbSX6muJVF2AK7uH1x4',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '4M8ThNHbNjda2cPwL8XZHS',
#   'song_artist_id': '2loEsOijJ6XiGzWYFXMIRk'},
#  {'song_id': '3AJwUDP919kvQ9QcozQPxg',
#   'song_name': 'Yellow',
#   'song_duration': 266773,
#   'song_popularity': 90,
#   'song_url': 'https://open.spotify.com/track/3AJwUDP919kvQ9QcozQPxg',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '6ZG5lRT77aJ3btmArcykra',
#   'song_artist_id': '4gzpq5DPGxSnKTe4SA8HAU'},
#  {'song_id': '7ov3TDp5D00Rnu5R1viX4w',
#   'song_name': 'New Woman (feat. ROSALÍA)',
#   'song_duration': 179789,
#   'song_popularity': 92,
#   'song_url': 'https://open.spotify.com/track/7ov3TDp5D00Rnu5R1viX4w',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '2ha4ucrONN0cihLMkP02Ch',
#   'song_artist_id': '5L1lO4eRHmJ7a0Q6csE5cT'},
#  {'song_id': '3qhlB30KknSejmIvZZLjOD',
#   'song_name': 'End of Beginning',
#   'song_duration': 159245,
#   'song_popularity': 92,
#   'song_url': 'https://open.spotify.com/track/3qhlB30KknSejmIvZZLjOD',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '4JDXBZdRPId4devseaAOKH',
#   'song_artist_id': '5p9HO3XC5P3BLxJs5Mtrhm'},
#  {'song_id': '2uqYupMHANxnwgeiXTZXzd',
#   'song_name': "Austin (Boots Stop Workin')",
#   'song_duration': 171782,
#   'song_popularity': 91,
#   'song_url': 'https://open.spotify.com/track/2uqYupMHANxnwgeiXTZXzd',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '40HsqPqeSR9Xe3IyAJWr6e',
#   'song_artist_id': '7Ez6lTtSMjMf2YSYpukP1I'},
#  {'song_id': '3JG1uFc40wfyrqaWC7iv0e',
#   'song_name': 'i like the way you kiss me',
#   'song_duration': 142514,
#   'song_popularity': 82,
#   'song_url': 'https://open.spotify.com/track/3JG1uFc40wfyrqaWC7iv0e',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '5nzSCZ7NhKvAysI0tmNOdD',
#   'song_artist_id': '0PCCGZ0wGLizHt2KZ7hhA2'},
#  {'song_id': '1BxfuPKGuaTgP7aM0Bbdwr',
#   'song_name': 'Cruel Summer',
#   'song_duration': 178426,
#   'song_popularity': 92,
#   'song_url': 'https://open.spotify.com/track/1BxfuPKGuaTgP7aM0Bbdwr',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '1NAmidJlEaVgA3MpcPFYGq',
#   'song_artist_id': '06HL4z0CvFAxyc27GXpf02'},
#  {'song_id': '5496lks6V3fh1mZAB6IAap',
#   'song_name': 'Alibi (with Pabllo Vittar & Yseult)',
#   'song_duration': 161655,
#   'song_popularity': 92,
#   'song_url': 'https://open.spotify.com/track/5496lks6V3fh1mZAB6IAap',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '2m0euKZUDcoyEXHIS5MFCq',
#   'song_artist_id': '5MraexJKZDrQYzS98kNwie'},
#  {'song_id': '3QaPy1KgI7nu9FJEQUgn6h',
#   'song_name': 'WILDFLOWER',
#   'song_duration': 261466,
#   'song_popularity': 91,
#   'song_url': 'https://open.spotify.com/track/3QaPy1KgI7nu9FJEQUgn6h',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'song_artist_id': '6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'song_id': '3Vr3zh0r7ALn8VLqCiRR10',
#   'song_name': 'Stargazing',
#   'song_duration': 172533,
#   'song_popularity': 92,
#   'song_url': 'https://open.spotify.com/track/3Vr3zh0r7ALn8VLqCiRR10',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '3VNxRarx9HUI5w7DHv0TBj',
#   'song_artist_id': '3bO19AOone0ubCsfDXDtYt'},
#  {'song_id': '102YUQbYmwdBXS7jwamI90',
#   'song_name': 'Good Graces',
#   'song_duration': 185265,
#   'song_popularity': 89,
#   'song_url': 'https://open.spotify.com/track/102YUQbYmwdBXS7jwamI90',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'song_artist_id': '74KM79TiuVKeVCqs8QtB0B'},
#  {'song_id': '51rfRCiUSvxXlCSCfIztBy',
#   'song_name': "I Love You, I'm Sorry",
#   'song_duration': 157146,
#   'song_popularity': 89,
#   'song_url': 'https://open.spotify.com/track/51rfRCiUSvxXlCSCfIztBy',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '56bdWeO40o3WfAD2Lja4dl',
#   'song_artist_id': '4tuJ0bMpJh08umKkEXKUI5'},
#  {'song_id': '42VsgItocQwOQC3XWZ8JNA',
#   'song_name': 'FE!N (feat. Playboi Carti)',
#   'song_duration': 191700,
#   'song_popularity': 90,
#   'song_url': 'https://open.spotify.com/track/42VsgItocQwOQC3XWZ8JNA',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '18NOKLkZETa4sWwLMIm0UZ',
#   'song_artist_id': '0Y5tJX1MQlPlqiwlOH1tJY'},
#  {'song_id': '7bywjHOc0wSjGGbj04XbVi',
#   'song_name': 'LUNA',
#   'song_duration': 196800,
#   'song_popularity': 90,
#   'song_url': 'https://open.spotify.com/track/7bywjHOc0wSjGGbj04XbVi',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '0lgs2Sa82lyX89nBUWyUy6',
#   'song_artist_id': '2LRoIwlKmHjgvigdNGBHNo'},
#  {'song_id': '42wdz3j7gstgUuhoFLCXqd',
#   'song_name': 'PELIGROSA',
#   'song_duration': 134930,
#   'song_popularity': 81,
#   'song_url': 'https://open.spotify.com/track/42wdz3j7gstgUuhoFLCXqd',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '6MikZBKCtKfPM4439yzBRz',
#   'song_artist_id': '7CvTknweLr9feJtRGrpDBy'},
#  {'song_id': '0UYnhUfnUj5adChuAXvLUB',
#   'song_name': 'Sailor Song',
#   'song_duration': 211978,
#   'song_popularity': 88,
#   'song_url': 'https://open.spotify.com/track/0UYnhUfnUj5adChuAXvLUB',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '4DWrYvfGXRE8ko5ZxlIpit',
#   'song_artist_id': '1iCnM8foFssWlPRLfAbIwo'},
#  {'song_id': '6Qyc6fS4DsZjB2mRW9DsQs',
#   'song_name': 'Iris',
#   'song_duration': 289533,
#   'song_popularity': 88,
#   'song_url': 'https://open.spotify.com/track/6Qyc6fS4DsZjB2mRW9DsQs',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '4UMjBXcRqIgMZ1XumU2x5T',
#   'song_artist_id': '2sil8z5kiy4r76CRTXxBCA'},
#  {'song_id': '2aYZaN5SmkRDLsrrV8GkBQ',
#   'song_name': 'LA PATRULLA',
#   'song_duration': 130614,
#   'song_popularity': 87,
#   'song_url': 'https://open.spotify.com/track/2aYZaN5SmkRDLsrrV8GkBQ',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '5kvw1bAOvzJdNi4hdgfaNf',
#   'song_artist_id': '12GqGscKJx3aE4t07u7eVZ'},
#  {'song_id': '2gmd7lY3QSzLh0xIY4cRvi',
#   'song_name': 'SE ME OLVIDA',
#   'song_duration': 225373,
#   'song_popularity': 86,
#   'song_url': 'https://open.spotify.com/track/2gmd7lY3QSzLh0xIY4cRvi',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '00ESTj1vBUkIbaTHaXaXu3',
#   'song_artist_id': '6B1hSmaLdOvChinK2Z7gfi'},
#  {'song_id': '7KA4W4McWYRpgf0fWsJZWB',
#   'song_name': 'See You Again (feat. Kali Uchis)',
#   'song_duration': 180386,
#   'song_popularity': 89,
#   'song_url': 'https://open.spotify.com/track/7KA4W4McWYRpgf0fWsJZWB',
#   'song_added_at': '2024-09-13T13:10:58Z',
#   'song_album_id': '2nkto6YNI4rUYTLqEwWJ3o',
#   'song_artist_id': '4V8LLVI7PbaPR0K2TGSxFF'}]

# %%
album_df = pd.DataFrame.from_dict(album_list)
artist_df = pd.DataFrame.from_dict(artist_list)
song_df = pd.DataFrame.from_dict(song_list)

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
album_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      46 non-null     object
#  1   album_name    46 non-null     object
#  2   release_date  46 non-null     datetime64[ns]
#  3   total_track   46 non-null     int64
#  4   url           46 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.2+ KB
#                  album_id            album_name release_date  total_track  \
# 0  10FLjwfpbxLmW8c25Xyc2N      Die With A Smile   2024-08-16            1
# 1  7aJuG4TFXa2hmE4z1yxc3n  HIT ME HARD AND SOFT   2024-05-17           10
# 2  3iPSVi54hsacKKl1xIR2eH        Short n' Sweet   2024-08-23           12
# 3  15XcLhiVMlSOipUddTNDnr                  MUSE   2024-07-19            7
# 4  5quMTd5zeI9yW5UDua8wS4              Espresso   2024-04-12            1
#
#                                                  url
# 0  https://open.spotify.com/album/10FLjwfpbxLmW8c...
# 1  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
# 2  https://open.spotify.com/album/3iPSVi54hsacKKl...
# 3  https://open.spotify.com/album/15XcLhiVMlSOipU...
# 4  https://open.spotify.com/album/5quMTd5zeI9yW5U...

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
artist_df.info()
artist_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 0 to 69
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   artist_id    60 non-null     object
#  1   artist_name  60 non-null     object
#  2   artist_url   60 non-null     object
# dtypes: object(3)
# memory usage: 1.9+ KB
#                 artist_id        artist_name  \
# 0  1HY2Jd0NmPuamShAr6KMms          Lady Gaga
# 1  0du5cEVh5yTK9QJze8zA0C         Bruno Mars
# 2  6qqNVTkY8uBg9cP3Jd7DAH      Billie Eilish
# 3  74KM79TiuVKeVCqs8QtB0B  Sabrina Carpenter
# 4  1oSPZhvZMIrWW5I41kPkkY              Jimin
#
#                                           artist_url
# 0  https://open.spotify.com/artist/1HY2Jd0NmPuamS...
# 1  https://open.spotify.com/artist/0du5cEVh5yTK9Q...
# 2  https://open.spotify.com/artist/6qqNVTkY8uBg9c...
# 3  https://open.spotify.com/artist/74KM79TiuVKeVC...
# 4  https://open.spotify.com/artist/1oSPZhvZMIrWW5...

# %%
song_df['song_added_at'] = pd.to_datetime(song_df['song_added_at'])
song_df.info()
song_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   song_id          50 non-null     object
#  1   song_name        50 non-null     object
#  2   song_duration    50 non-null     int64
#  3   song_popularity  50 non-null     int64
#  4   song_url         50 non-null     object
#  5   song_added_at    50 non-null     datetime64[ns, UTC]
#  6   song_album_id    50 non-null     object
#  7   song_artist_id   50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.2+ KB
#                   song_id           song_name  song_duration  song_popularity  \
# 0  2plbrEY59IikOBgBGLjaoe    Die With A Smile         251667               98
# 1  6dOtVTDdiauQNBQEDOtlAB  BIRDS OF A FEATHER         210373              100
# 2  5G2f63n7IPVPPjfNIGih7Q               Taste         157279               95
# 3  7tI8dRuH2Yc6RuoTjxo4dU                 Who         170887               94
# 4  2qSkIjg1o9h3YT9RAgYN75            Espresso         175459               97
#
#                                             song_url  \
# 0  https://open.spotify.com/track/2plbrEY59IikOBg...
# 1  https://open.spotify.com/track/6dOtVTDdiauQNBQ...
# 2  https://open.spotify.com/track/5G2f63n7IPVPPjf...
# 3  https://open.spotify.com/track/7tI8dRuH2Yc6Ruo...
# 4  https://open.spotify.com/track/2qSkIjg1o9h3YT9...
#
#               song_added_at           song_album_id          song_artist_id
# 0 2024-09-13 13:10:58+00:00  10FLjwfpbxLmW8c25Xyc2N  1HY2Jd0NmPuamShAr6KMms
# 1 2024-09-13 13:10:58+00:00  7aJuG4TFXa2hmE4z1yxc3n  6qqNVTkY8uBg9cP3Jd7DAH
# 2 2024-09-13 13:10:58+00:00  3iPSVi54hsacKKl1xIR2eH  74KM79TiuVKeVCqs8QtB0B
# 3 2024-09-13 13:10:58+00:00  15XcLhiVMlSOipUddTNDnr  1oSPZhvZMIrWW5I41kPkkY
# 4 2024-09-13 13:10:58+00:00  5quMTd5zeI9yW5UDua8wS4  74KM79TiuVKeVCqs8QtB0B
